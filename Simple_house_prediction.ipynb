# %% [markdown]
# <a href="https://colab.research.google.com/github/sftSalman/tensorflowBasic/blob/main/Simple_house_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf 
import numpy as np 
from tensorflow import keras

# %%
def house_predict():
  #x = None
  #y = None
  x = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
  y = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)
  model = tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])
  #model.compile(optimizer = None , loss = None )
  model.compile(optimizer='sgd', loss='mean_squared_error')
  #model.fit(None,None,epchos = None)
  model.fit(x,y,epochs=500)

  return model

# %%
model = house_predict()
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 509ms/step - loss: 8.4452
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 6.8448
# Epoch 3/500
# 1/1 [==============================] - 0s 13ms/step - loss: 5.5816
# Epoch 4/500
# 1/1 [==============================] - 0s 12ms/step - loss: 4.5838
# Epoch 5/500
# 1/1 [==============================] - 0s 14ms/step - loss: 3.7947
# Epoch 6/500
# 1/1 [==============================] - 0s 14ms/step - loss: 3.1701
# Epoch 7/500
# 1/1 [==============================] - 0s 9ms/step - loss: 2.6749
# Epoch 8/500
# 1/1 [==============================] - 0s 11ms/step - loss: 2.2815
# Epoch 9/500
# 1/1 [==============================] - 0s 9ms/step - loss: 1.9684
# Epoch 10/500
# 1/1 [==============================] - 0s 15ms/step - loss: 1.7186
# Epoch 11/500
# 1/1 [==============================] - 0s 10ms/step - loss: 1.5185
# Epoch 12/500
# 1/1 [==============================] - 0s 5ms/step - loss: 1.3576
# ...

# %%
new_y = 7.0
prediction = model.predict([new_y])[0]
print(prediction)
# Out:
# [12.990517]
